# %%
import seaborn as sns
import matplotlib.pyplot as plt

print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris = sns.load_dataset('iris')
print(iris.columns)
sns.lineplot(x="sepal_length", y="sepal_width", data=iris)
plt.title("iris dataset")
plt.xlabel("x label")
plt.ylabel('y label')
plt.grid(True , linestyle="--")
plt.tight_layout()
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
# C:\Users\Rohini\AppData\Local\Temp\ipykernel_5680\1380652616.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
iris = sns.load_dataset('iris')
print(iris.columns)
plt.figure(figsize=(8, 5))
sns.barplot(x="sepal_length", y="sepal_width", data=iris, )
plt.title("iris dataset")
plt.xlabel("x label")

plt.ylabel('y label')
plt.grid(True , linestyle="--")
plt.tight_layout()
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris = sns.load_dataset('iris')
print(iris.columns)
sns.histplot(x="sepal_length", y="sepal_width", data=iris)
plt.title("iris dataset")
plt.xlabel("sepal_length")
plt.ylabel('sepal_width')
plt.grid(True , linestyle="--")
plt.tight_layout()
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris = sns.load_dataset('iris')
print(iris.columns)
sns.scatterplot(x="sepal_length", y="sepal_width", data=iris)
plt.title("iris dataset")
plt.xlabel("x label")
plt.ylabel('y label')
plt.grid(True , linestyle="--")
plt.tight_layout()
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
