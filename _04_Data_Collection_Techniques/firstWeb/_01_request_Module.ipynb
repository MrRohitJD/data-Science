# %%
import  requests

# %%
for i in range(1, 51):
    x = requests.get(f"https://books.toscrape.com/catalogue/page-{i}.html")

    with open(f"htmls/page-{i}.html", "w", encoding="utf-8") as f:
        f.write(x.text)
    print(f"created file {i}")
