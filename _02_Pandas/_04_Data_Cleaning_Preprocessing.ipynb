# %% [markdown]
# ## null values Cleaning

# %%
import pandas as pd

# %%
df = pd.read_csv("https://codewithharry.nyc3.cdn.digitaloceanspaces.com/dashboard/lesson/data-cleaning-preprocessing-1745500885184/1745501008647-data_cleaning_sample.csv")
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.isnull()
# Out:
#     Name    Age   City  Gender  Email  Join Date
# 0  False  False  False   False  False      False
# 1  False   True  False   False  False      False
# 2  False  False  False   False  False      False
# 3  False   True  False   False  False      False
# 4  False  False  False   False  False      False
# 5   True  False  False   False  False       True
# 6  False  False  False   False  False      False
# 7  False  False  False   False  False      False
# 8  False   True  False   False  False      False

# %%
df.isnull().sum()
# Out:
# Name         1
# Age          3
# City         0
# Gender       0
# Email        0
# Join Date    1
# dtype: int64

# %%
df.shape
# Out:
# (9, 6)

# %%
df.dropna()
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %%
df.dropna(axis=1)
# Out:
#           City Gender              Email
# 0     New York      F  alice@example.com
# 1        Delhi      M    charlie@example
# 2  Los Angeles      M    bob@example.com
# 3        Delhi      M    charlie@example
# 4       Mumbai      M  david@example.com
# 5        Delhi      F     eve@domain.com
# 6     New York      F  alice@example.com
# 7     New York      F  alice@example.com
# 8        Delhi      M    charlie@example

# %%
df1 = df.fillna(0)

# %%
df1.isnull().sum()
# Out:
# Name         0
# Age          0
# City         0
# Gender       0
# Email        0
# Join Date    0
# dtype: int64

# %%
df["Age"].fillna(df["Age"].mean())
# Out:
# 0    25.000000
# 1    25.833333
# 2    30.000000
# 3    25.833333
# 4    22.000000
# 5    28.000000
# 6    25.000000
# 7    25.000000
# 8    25.833333
# Name: Age, dtype: float64

# %% [markdown]
# ## duplicate

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df1 = df.drop_duplicates()

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df.duplicated(["Age", "Name"])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df["Name"].str.lower()
# Out:
# 0      alice
# 1    charlie
# 2        bob
# 3    charlie
# 4      david
# 5        NaN
# 6      alice
# 7      alice
# 8    charlie
# Name: Name, dtype: object

# %%
df["City"].str.contains("Delhi", case=False).sum()
# Out:
# np.int64(4)

# %%
df["Email"].str.split('@')
# Out:
# 0    [alice, example.com]
# 1      [charlie, example]
# 2      [bob, example.com]
# 3      [charlie, example]
# 4    [david, example.com]
# 5       [eve, domain.com]
# 6    [alice, example.com]
# 7    [alice, example.com]
# 8      [charlie, example]
# Name: Email, dtype: object

# %%
type(df["Email"].str.split('@'))
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date Age Group
# 0    Alice  25.0     New York    NaN  alice@example.com  01-05-2021     adult
# 1  Charlie   NaN        Delhi    NaN    charlie@example  20-07-2021     adult
# 2      Bob  30.0  Los Angeles    NaN    bob@example.com  15-06-2020     adult
# 3  Charlie   NaN        Delhi    NaN    charlie@example  20-07-2021     adult
# 4    David  22.0       Mumbai    NaN  david@example.com  12-11-2019     adult
# 5      NaN  28.0        Delhi    NaN     eve@domain.com         NaN     adult
# 6    Alice  25.0     New York    NaN  alice@example.com  01-05-2021     adult
# 7    Alice  25.0     New York    NaN  alice@example.com  01-05-2021     adult
# 8  Charlie   NaN        Delhi    NaN    charlie@example  20-07-2021     adult

# %%
df['Age Group'] =df["Age"].apply(lambda x: "minor" if x<18 else "adult")

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date Age Group
# 0    Alice  25.0     New York    NaN  alice@example.com  01-05-2021     adult
# 1  Charlie   NaN        Delhi    NaN    charlie@example  20-07-2021     adult
# 2      Bob  30.0  Los Angeles    NaN    bob@example.com  15-06-2020     adult
# 3  Charlie   NaN        Delhi    NaN    charlie@example  20-07-2021     adult
# 4    David  22.0       Mumbai    NaN  david@example.com  12-11-2019     adult
# 5      NaN  28.0        Delhi    NaN     eve@domain.com         NaN     adult
# 6    Alice  25.0     New York    NaN  alice@example.com  01-05-2021     adult
# 7    Alice  25.0     New York    NaN  alice@example.com  01-05-2021     adult
# 8  Charlie   NaN        Delhi    NaN    charlie@example  20-07-2021     adult

# %%
df1 = df.dropna(subset=['Gender']).copy()
df1
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
gender_map = {"M": "Male", "F": "Female"}
df1["Gender"] = df1["Gender"].map(gender_map)
df1
# Out:
#       Name   Age         City  Gender              Email   Join Date
# 0    Alice  25.0     New York  Female  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi    Male    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles    Male    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi    Male    charlie@example  20-07-2021
# 4    David  22.0       Mumbai    Male  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi  Female     eve@domain.com         NaN
# 6    Alice  25.0     New York  Female  alice@example.com  01-05-2021
# 7    Alice  25.0     New York  Female  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi    Male    charlie@example  20-07-2021

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df['City'] = df["City"].replace({"Delhi": "new Delhi", "Mumbai": "Mumbai"})
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN    new Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN    new Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0    new Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN    new Delhi      M    charlie@example  20-07-2021
