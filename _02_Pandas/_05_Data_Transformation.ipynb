# %% [markdown]
# ## Sorting

# %%
import pandas as pd

# %%
df = pd.read_csv("https://codewithharry.nyc3.cdn.digitaloceanspaces.com/dashboard/lesson/creating-dataframes-1745077860781/1745500125912-data.csv")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df1 = df.sort_values('Year', ascending= False).copy()
df1
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df1.sort_values(['Year', "IMDb"],  ascending= False)
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df1.reset_index()
# Out:
#     index               Actor                      Film  Year  \
# 0       0      Shah Rukh Khan                   Pathaan  2023
# 1       3       Ranbir Kapoor                Brahmastra  2022
# 2       9       Kartik Aaryan         Bhool Bhulaiyaa 2  2022
# 3       7      Hrithik Roshan                       War  2019
# 4       8        Akshay Kumar                Good Newwz  2019
# 5      11       Vicky Kaushal  Uri: The Surgical Strike  2019
# 6       6       Rajkummar Rao                     Stree  2018
# 7       5  Ayushmann Khurrana                 Andhadhun  2018
# 8       4       Ranveer Singh                 Padmaavat  2018
# 9       1         Salman Khan           Tiger Zinda Hai  2017
# 10     10        Varun Dhawan     Badrinath Ki Dulhania  2017
# 11      2          Aamir Khan                    Dangal  2016
#
#               Genre  BoxOffice(INR Crore)  IMDb
# 0            Action                  1050   7.2
# 1           Fantasy                   431   5.6
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Actor                 12 non-null     object
#  1   Film                  12 non-null     object
#  2   Year                  12 non-null     int64
#  3   Genre                 12 non-null     object
#  4   BoxOffice(INR Crore)  12 non-null     int64
#  5   IMDb                  12 non-null     float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 672.0+ bytes

# %%
df1.reset_index(drop= True, inplace= True)
df1
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 2        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3       Hrithik Roshan                       War  2019           Action
# 4         Akshay Kumar                Good Newwz  2019           Comedy
# 5        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 8        Ranveer Singh                 Padmaavat  2018       Historical
# 9          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11          Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df1.loc[1,'Actor']
# Out:
# 'Ranbir Kapoor'

# %%
df1
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 2        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3       Hrithik Roshan                       War  2019           Action
# 4         Akshay Kumar                Good Newwz  2019           Comedy
# 5        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 8        Ranveer Singh                 Padmaavat  2018       Historical
# 9          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11          Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values(['Year',"IMDb"])
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_index()
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...
